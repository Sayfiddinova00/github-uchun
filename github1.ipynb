# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayfiddinova00/github-uchun/blob/main/github1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
obj=Series([4,7,6,-5,-4.5])

# %%
print(obj)
# Out:
# 0    4.0
# 1    7.0
# 2    6.0
# 3   -5.0
# 4   -4.5
# dtype: float64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
obj.values
# Out:
# array([ 4. ,  7. ,  6. , -5. , -4.5])

# %%
obj[0]
# Out:
# np.float64(4.0)

# %%
obj2=Series([1,2,3], index=['a', 'b', 'c'])

# %%
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4bc0346e-5dbe-4d91-9655-7cccf1a67547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bc0346e-5dbe-4d91-9655-7cccf1a67547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Saving talabalar.csv to talabalar.csv

# %%
df = pd.read_csv('pandas_homework_dirty_data_2150_rows.csv')
df.head()
# Out:
#    order_id    shop  product     city amount   shop_date
# 0         1  Shop B   Laptop  Bukhara   3950  16.01.2025
# 1         2  Shop E   Laptop      NaN   1393         NaN
# 2         3     NaN  Monitor      NaN  1,200  17.09.2025
# 3         4     NaN      NaN  Bukhara   2456  21.01.2025
# 4         5     NaN   Laptop      NaN   4715  14.01.2025

# %%
df.isnull().sum()
# Out:
# order_id       0
# shop         610
# product      601
# city         618
# amount       335
# shop_date    224
# dtype: int64

# %%
df.shape
# Out:
# (2150, 6)

# %%
df.isnull().any()

# %%
f.isnull().any()f.isnull().any()

# %%
df.head

# %%
df["name"] = df["name"].str.strip()

# %%
df.["gender"]
